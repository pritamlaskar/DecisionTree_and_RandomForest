# %%
# Pandas, NumPy, Matplotlib, and Seaborn
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# Machine Learning Algorithms and Scaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# Evaluation Metrics
from sklearn.metrics import accuracy_score, f1_score

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("C:/Users/Pritam Laskar/Documents/Projects/Audit Risk Prediction/audit_data.csv")
trial = pd.read_csv("C:/Users/Pritam Laskar/Documents/Projects/Audit Risk Prediction/trial.csv")

# %%
data.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
# 3          3.89           6    0.00      0.2   0.000   10.80      0.6   6.480
# 4          3.89           6    0.00      0.2   0.000    0.08      0.2   0.016
#
#    TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...     0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...     0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...     0.4        0   0.2     0.0    2.0          1.548
# 3  10.80      6.0  ...     0.4        0   0.2     0.0    4.4         17.530
# 4   0.08      5.0  ...     0.4        0   0.2     0.0    2.0          1.416
#
# ...

# %%
trial.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  numbers  \
# 0          3.89          23    4.18        6    2.50        2   6.68      5.0
# 1          3.89           6    0.00        2    4.83        2   4.83      5.0
# 2          3.89           6    0.51        2    0.23        2   0.74      5.0
# 3          3.89           6    0.00        2   10.80        6  10.80      6.0
# 4          3.89           6    0.00        2    0.08        2   0.08      5.0
#
#    Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  History  \
# 0      2         3.38            2         2     0           2        0
# 1      2         0.94            2         2     0           2        0
# 2      2         0.00            2         2     0           2        0
# 3      6        11.75            6         2     0           2        0
# 4      2         0.00            2         2     0           2        0
#
#    History_score  Score  Risk
# 0              2    2.4     1
# ...

# %% [markdown]
# # Data Preprocessing I

# %%
data.shape
# Out:
# (776, 27)

# %%
trial.shape
# Out:
# (776, 18)

# %%
trial.duplicated().sum()
# Out:
# 13

# %%
data.duplicated().sum()
# Out:
# 13

# %%
# Removing Duplicates

data = data.drop_duplicates()
trial = trial.drop_duplicates()

# %%
(data.isnull().sum()/len(data)*100)
# Out:
# Sector_score      0.000000
# LOCATION_ID       0.000000
# PARA_A            0.000000
# Score_A           0.000000
# Risk_A            0.000000
# PARA_B            0.000000
# Score_B           0.000000
# Risk_B            0.000000
# TOTAL             0.000000
# numbers           0.000000
# Score_B.1         0.000000
# Risk_C            0.000000
# Money_Value       0.131062
# Score_MV          0.000000
# Risk_D            0.000000
# District_Loss     0.000000
# PROB              0.000000
# RiSk_E            0.000000
# History           0.000000
# Prob              0.000000
# Risk_F            0.000000
# Score             0.000000
# Inherent_Risk     0.000000
# CONTROL_RISK      0.000000
# Detection_Risk    0.000000
# Audit_Risk        0.000000
# Risk              0.000000
# dtype: float64

# %%
(trial.isnull().sum()/len(trial)*100)
# Out:
# Sector_score     0.000000
# LOCATION_ID      0.000000
# PARA_A           0.000000
# SCORE_A          0.000000
# PARA_B           0.000000
# SCORE_B          0.000000
# TOTAL            0.000000
# numbers          0.000000
# Marks            0.000000
# Money_Value      0.131062
# MONEY_Marks      0.000000
# District         0.000000
# Loss             0.000000
# LOSS_SCORE       0.000000
# History          0.000000
# History_score    0.000000
# Score            0.000000
# Risk             0.000000
# dtype: float64

# %%
# Removing null

data['Money_Value'] = data['Money_Value'].fillna(data['Money_Value'].mean())
trial['Money_Value'] = trial['Money_Value'].fillna(trial['Money_Value'].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 775
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sector_score    763 non-null    float64
#  1   LOCATION_ID     763 non-null    object
#  2   PARA_A          763 non-null    float64
#  3   Score_A         763 non-null    float64
#  4   Risk_A          763 non-null    float64
#  5   PARA_B          763 non-null    float64
#  6   Score_B         763 non-null    float64
#  7   Risk_B          763 non-null    float64
#  8   TOTAL           763 non-null    float64
#  9   numbers         763 non-null    float64
#  10  Score_B.1       763 non-null    float64
#  11  Risk_C          763 non-null    float64
#  12  Money_Value     763 non-null    float64
#  13  Score_MV        763 non-null    float64
#  14  Risk_D          763 non-null    float64
#  15  District_Loss   763 non-null    int64
#  16  PROB            763 non-null    float64
# ...

# %%
trial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 0 to 775
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sector_score   763 non-null    float64
#  1   LOCATION_ID    763 non-null    object
#  2   PARA_A         763 non-null    float64
#  3   SCORE_A        763 non-null    int64
#  4   PARA_B         763 non-null    float64
#  5   SCORE_B        763 non-null    int64
#  6   TOTAL          763 non-null    float64
#  7   numbers        763 non-null    float64
#  8   Marks          763 non-null    int64
#  9   Money_Value    763 non-null    float64
#  10  MONEY_Marks    763 non-null    int64
#  11  District       763 non-null    int64
#  12  Loss           763 non-null    int64
#  13  LOSS_SCORE     763 non-null    int64
#  14  History        763 non-null    int64
#  15  History_score  763 non-null    int64
#  16  Score          763 non-null    float64
# ...

# %%
# Checking Outliers:

pd.set_option('display.max_columns', None)
data.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A       PARA_B  \
# count    763.000000  763.000000  763.000000  763.000000   763.000000
# mean      19.721311    2.491298    0.353866    1.373919    10.983474
# std       24.132399    5.718259    0.174398    3.465152    50.489113
# min        1.850000    0.000000    0.200000    0.000000     0.000000
# 25%        2.370000    0.260000    0.200000    0.052000     0.000000
# 50%        3.890000    0.900000    0.200000    0.180000     0.440000
# 75%       55.570000    2.515000    0.600000    1.509000     4.365000
# max       59.850000   85.000000    0.600000   51.000000  1264.630000
#
#           Score_B      Risk_B        TOTAL     numbers   Score_B.1  \
# count  763.000000  763.000000   763.000000  763.000000  763.000000
# mean     0.315072    6.441822    13.442532    5.068807    0.224115
# std      0.170597   30.316831    51.719679    0.266546    0.080974
# min      0.200000    0.000000     0.000000    5.000000    0.200000
# ...

# %%
# Outlier Removal in Data (Train)

columns = ['Sector_score', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B', 'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C', 'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss']

Q3 = data[columns].quantile(.75)
Q1 = data[columns].quantile(.25)
IQR = Q3 - Q1
UL = Q3 + 1.5*IQR
LL = Q1 - 1.5*IQR

for column in columns:
    data[column] = np.where(data[column] > UL[column], UL[column], np.where(data[column] < LL[column], LL[column], data[column]))

# %%
trial.describe()
# Out:
#        Sector_score      PARA_A     SCORE_A       PARA_B     SCORE_B  \
# count    763.000000  763.000000  763.000000   763.000000  763.000000
# mean      19.721311    2.491298    3.538663    10.983474    3.150721
# std       24.132399    5.718259    1.743985    50.489113    1.705967
# min        1.850000    0.000000    2.000000     0.000000    2.000000
# 25%        2.370000    0.260000    2.000000     0.000000    2.000000
# 50%        3.890000    0.900000    2.000000     0.440000    2.000000
# 75%       55.570000    2.515000    6.000000     4.365000    4.000000
# max       59.850000   85.000000    6.000000  1264.630000    6.000000
#
#              TOTAL     numbers       Marks  Money_Value  MONEY_Marks  \
# count   763.000000  763.000000  763.000000   763.000000   763.000000
# mean     13.442532    5.068807    2.241153    14.378824     2.925295
# std      51.719679    0.266546    0.809740    67.103095     1.606557
# ...

# %%
# Outlier Removal in Trial (Test)

columns = ['Sector_score', 'PARA_A', 'SCORE_A', 'PARA_B', 'SCORE_B', 'TOTAL', 'numbers', 'Marks', 'Money_Value']

Q3 = trial[columns].quantile(.75)
Q1 = trial[columns].quantile(.25)
IQR = Q3 - Q1
UL = Q3 + 1.5*IQR
LL = Q1 - 1.5*IQR

for column in columns:
    trial[column] = np.where(trial[column] > UL[column], UL[column], np.where(trial[column] < LL[column], LL[column], trial[column]))

# %% [markdown]
# # Label Encoding

# %%
data.dtypes
# Out:
# Sector_score      float64
# LOCATION_ID        object
# PARA_A            float64
# Score_A           float64
# Risk_A            float64
# PARA_B            float64
# Score_B           float64
# Risk_B            float64
# TOTAL             float64
# numbers           float64
# Score_B.1         float64
# Risk_C            float64
# Money_Value       float64
# Score_MV          float64
# Risk_D            float64
# District_Loss     float64
# PROB              float64
# RiSk_E            float64
# History             int64
# Prob              float64
# Risk_F            float64
# Score             float64
# Inherent_Risk     float64
# CONTROL_RISK      float64
# Detection_Risk    float64
# Audit_Risk        float64
# Risk                int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

data['LOCATION_ID'] = encoder.fit_transform(data['LOCATION_ID'])
trial['LOCATION_ID'] = encoder.fit_transform(trial['LOCATION_ID'])

# %% [markdown]
# # Multicollinearity Check

# %%
plt.figure(figsize = (20,10))
sns.heatmap(data.corr(), annot = True, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %%
# As multiple columns have correlation over .75, we will drop them one by one
# To decide which columns to drop, we will call VIF
# When two columns have higher correlation (> .75), we shall drop the column having higher VIF between those two columns
# We shall take note that we shall not drop columns present in trial dataset (our test dataset)

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data['features'] = data.columns

vif_data['VIF'] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
vif_data
# Out:
#           features         VIF
# 0     Sector_score    1.363793
# 1      LOCATION_ID    1.048025
# 2           PARA_A   96.803705
# 3          Score_A    6.874512
# 4           Risk_A   90.221067
# 5           PARA_B  111.558902
# 6          Score_B   25.067233
# 7           Risk_B  124.818126
# 8            TOTAL   26.244464
# 9          numbers    0.000000
# 10       Score_B.1    0.004108
# 11          Risk_C    0.000000
# 12     Money_Value   43.116188
# 13        Score_MV  154.746921
# 14          Risk_D  243.983090
# 15   District_Loss    0.000000
# 16            PROB    1.295643
# 17          RiSk_E         inf
# 18         History  134.046223
# 19            Prob    7.438953
# 20          Risk_F         inf
# 21           Score   40.472408
# 22   Inherent_Risk    3.278469
# 23    CONTROL_RISK         inf
# 24  Detection_Risk    0.000000
# 25      Audit_Risk    3.236774
# 26            Risk    4.264302

# %%
trial.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'SCORE_A', 'PARA_B', 'SCORE_B',
#        'TOTAL', 'numbers', 'Marks', 'Money_Value', 'MONEY_Marks', 'District',
#        'Loss', 'LOSS_SCORE', 'History', 'History_score', 'Score', 'Risk'],
#       dtype='object')

# %%
# Correlation between Risk A and PARA A is 0.99. As PARA A is present in trial set, we can drop Risk A.
# Correlation between Risk B and PARA B is 0.99. As PARA B is present in trial set, we can drop Risk B.
# Correlation between Risk D and Money Value is 0.99. As Money Value is present in trial set, we shall drop Risk D.
# Correlation between History and Prob is 0.99. As History is present in trial set, we shall drop Prob.
# Correlation between Risk F and CONTROL_Risk is 0.76. We will drop the one with higher VIF. 
# However, as VIF is infinity and none of them present in the trial set, we can drop both.
# We will proceed with the same procedure:

data.drop(['Score_MV', 'Inherent_Risk', 'Risk_A', 'Risk_B', 'Risk_D', 'Prob', 'Risk_F', 'CONTROL_RISK'], axis = 1,  inplace=True)

# %%
data.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'PARA_B', 'Score_B',
#        'TOTAL', 'numbers', 'Score_B.1', 'Risk_C', 'Money_Value',
#        'District_Loss', 'PROB', 'RiSk_E', 'History', 'Score', 'Detection_Risk',
#        'Audit_Risk', 'Risk'],
#       dtype='object')

# %% [markdown]
# # Data Processing II

# %%
data.shape
# Out:
# (763, 19)

# %%
trial.shape
# Out:
# (763, 18)

# %%
data.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'PARA_B', 'Score_B',
#        'TOTAL', 'numbers', 'Score_B.1', 'Risk_C', 'Money_Value',
#        'District_Loss', 'PROB', 'RiSk_E', 'History', 'Score', 'Detection_Risk',
#        'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
trial.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'SCORE_A', 'PARA_B', 'SCORE_B',
#        'TOTAL', 'numbers', 'Marks', 'Money_Value', 'MONEY_Marks', 'District',
#        'Loss', 'LOSS_SCORE', 'History', 'History_score', 'Score', 'Risk'],
#       dtype='object')

# %%
data.drop(['Score_B.1', 'Risk_C', 'District_Loss', 'PROB', 'RiSk_E', 'Detection_Risk', 'Audit_Risk'], axis = 1, inplace = True)

# %%
trial.drop(['Marks', 'LOSS_SCORE', 'History_score'], axis = 1, inplace = True)

# %%
trial.drop(['MONEY_Marks', 'District', 'Loss'], axis = 1, inplace= True)

# %%
data.shape
# Out:
# (763, 12)

# %%
trial.shape
# Out:
# (763, 12)

# %%
train_x = data.drop(['Risk'], axis = 1)
train_y = data['Risk']

# %%
test_x = trial.drop(['Risk'], axis = 1)
test_y = trial['Risk']

# %%
train_x.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'PARA_B', 'Score_B',
#        'TOTAL', 'numbers', 'Money_Value', 'History', 'Score'],
#       dtype='object')

# %%
test_x.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'SCORE_A', 'PARA_B', 'SCORE_B',
#        'TOTAL', 'numbers', 'Money_Value', 'History', 'Score'],
#       dtype='object')

# %%
train_x.dtypes
# Out:
# Sector_score    float64
# LOCATION_ID       int32
# PARA_A          float64
# Score_A         float64
# PARA_B          float64
# Score_B         float64
# TOTAL           float64
# numbers         float64
# Money_Value     float64
# History           int64
# Score           float64
# dtype: object

# %%
test_x.dtypes
# Out:
# Sector_score    float64
# LOCATION_ID       int32
# PARA_A          float64
# SCORE_A         float64
# PARA_B          float64
# SCORE_B         float64
# TOTAL           float64
# numbers         float64
# Money_Value     float64
# History           int64
# Score           float64
# dtype: object

# %% [markdown]
# # Machine Learning Algorithms

# %% [markdown]
# We will use the following algorithms:
#
# 1. Logistic Regression
# 2. Decision Tree
# 3. Random Forest

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()

# Convert feature names in the test dataset to match the case of training data (Error received earlier)
test_x.rename(columns = {'SCORE_A': 'Score_A', 'SCORE_B': 'Score_B'}, inplace = True)

lr_model = lr.fit(train_x, train_y)
y_predlr = lr_model.predict(test_x)

# %%
accuracy_lr = accuracy_score(test_y, y_predlr)
f1_lr = f1_score(test_y, y_predlr)
print('Accuracy With Logistic Regression = ', accuracy_lr)
print('F1 Score With Logistic Regression = ', f1_lr)
# Out:
# Accuracy With Logistic Regression =  0.3944954128440367
# F1 Score With Logistic Regression =  0.0905511811023622

# %% [markdown]
# ## Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()

dt_model = dt.fit(train_x, train_y)
y_preddt = dt_model.predict(test_x)

# %%
accuracy_dt = accuracy_score(test_y, y_preddt)
f1_dt = f1_score(test_y, y_preddt)
print('Accuracy With Decision Tree Classifier = ', accuracy_dt)
print('F1 Score With Decision Tree Classifier = ', f1_dt)
# Out:
# Accuracy With Decision Tree Classifier =  0.7509829619921363
# F1 Score With Decision Tree Classifier =  0.7564102564102563

# %% [markdown]
# ## Random Forest Classifier

# %%
rf = RandomForestClassifier()

rf_model = rf.fit(train_x, train_y)
y_predrf = rf_model.predict(test_x)

# %%
accuracy_rf = accuracy_score(test_y, y_predrf)
f1_rf = f1_score(test_y, y_predrf)
print('Accuracy With Decision Tree Classifier = ', accuracy_rf)
print('F1 Score With Decision Tree Classifier = ', f1_rf)
# Out:
# Accuracy With Decision Tree Classifier =  0.7522935779816514
# F1 Score With Decision Tree Classifier =  0.7580025608194623

# %% [markdown]
# # Scaling Our Data

# %% [markdown]
# Since Decison Tree has higher F1 score and accuracy score among all the algorithms used, we will go with Decision Tree Classifier.

# %%
sc = StandardScaler()

# Employing Logistic Regression
train_x2 = sc.fit_transform(train_x)
test_x2 = sc.transform(test_x)
dt_model2 = dt.fit(train_x2, train_y)
y_pred2 = dt_model2.predict(test_x2)

# Evaluating Scaled Model
accuracy = accuracy_score(test_y, y_pred2)
f1 = f1_score(test_y, y_pred2)
print('Scaled Accuracy With Logistic Regression = ', accuracy)
print('Scaled F1 Score With Logistic Regression = ', f1)
# Out:
# Scaled Accuracy With Logistic Regression =  0.7588466579292268
# Scaled F1 Score With Logistic Regression =  0.7659033078880407

# %%
# Lets View Our Test and Prediction Data:

pred_data = pd.DataFrame(np.column_stack((y_pred2, test_y)), columns = ['Prediction', 'Test'])
pred_data
# Out:
#      Prediction  Test
# 0             1     1
# 1             0     0
# 2             0     0
# 3             1     1
# 4             0     0
# ..          ...   ...
# 758           0     0
# 759           0     0
# 760           0     0
# 761           0     0
# 762           0     0
#
# [763 rows x 2 columns]

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this audit risk prediction project, we embarked on a comprehensive data analysis journey, leveraging various data preprocessing techniques and machine learning algorithms to develop an effective predictive model.
#
# Our initial steps involved importing essential libraries and loading two datasets, "data" and "trial." We ensured data integrity by addressing issues such as duplicates and missing values, thus creating a clean foundation for our analysis. Label encoding was applied to convert categorical variables into a numerical format, making them suitable for machine learning algorithms.
#
# A critical aspect of our analysis was data preprocessing. We  examined feature correlations to identify and remove highly correlated attributes, optimizing the model's performance. We also took into consideration the availability of features in the trial dataset, leading to the final selection of relevant features for modeling.
#
# We applied three machine learning algorithms: Logistic Regression, Decision Tree Classifier, and Random Forest Classifier. Among these, the Decision Tree Classifier demonstrated the best performance, exhibiting high accuracy and F1 score. To further enhance model performance, we introduced standard scaling to our data, resulting in improved accuracy and F1 score metrics.
#
# In conclusion, this project highlights the significance of data preprocessing and feature engineering in the development of a robust predictive model for audit risk assessment. The Decision Tree Classifier, when combined with appropriate feature selection and scaling, emerged as the most effective approach for this specific task. Nevertheless, continuous optimization and fine-tuning remain essential to meet evolving requirements and ensure the model's reliability in real-world audit risk prediction scenarios.
